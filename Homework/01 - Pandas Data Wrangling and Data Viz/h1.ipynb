# %% [markdown]
# # Homework 1: A sinister homework
#
# By the end of this homework, we expect you to be able to:
#
# 1. Load data and handle data using pandas;
# 2. Navigate the documentation of Python packages by yourself;
# 3. Filter and tidy up noisy real-world datasets;
# 4. Aggregate your data in different (and hopefully helpful) ways;
# 5. Create meaningful visualizations to analyze the data;
# 6. Communicate your findings in a clear and concise manner
#
#
# ---
#
# ## Important Dates
# - Homework release: Fri 13 Oct 2023
# - **Homework due:** Fri 27 Oct 2023, 23:59
# - Grade release: Mon 06 Nov 2023
#
# ---
#
# ## Some rules
# 1. You are allowed to use any built-in Python library that comes with Anaconda. If you want to use an external library, you may do so, but must justify your choice.
#
# 2. Make sure you use the `data` folder provided in the repository in read-only mode. (Or alternatively, be sure you don’t change any of the files.)
#
# 3. Be sure to provide a concise textual description of your thought process, the assumptions you made, the solution you implemented, and explanations for your answers. A notebook that only has code cells will not suffice.
#
# 4. For questions containing the **/Discuss:/** prefix, answer not with code, but with a textual explanation **(in markdown)**.
#
# 5. Back up any hypotheses and claims with data, since this is an important aspect of the course.
#
# 6. Please write all your comments in **English**, and use meaningful variable names in your code. Your repo should have a single notebook (plus the required data files) in the master/main branch. **If there are multiple notebooks present, we will not grade anything.**
#
# 7. We will **not run your notebook for you!** Rather, we will grade it as is, which means that only the results contained in your evaluated code cells will be considered, and we will not see the results in unevaluated code cells. Thus, be sure to hand in a **fully-run and evaluated notebook**. In order to check whether everything looks as intended, you can check the rendered notebook on the GitHub website once you have pushed your solution there.
#
# 8. In continuation to the previous point, interactive plots, such as those generated using the `plotly` package, should be strictly avoided!
#
# 9. Make sure to print results and/or dataframes that confirm you have properly addressed the task.
#
#
# ---
#
# ##  Context
#
# Congratulations! You have just been hired as a data scientist at "The ByteBlasters", EPFL’s amateur baseball club. The team's manager, Mr. Russo, an eccentric millionaire with an innovative plan to dominate the Swiss baseball league, believes hiring left-handed pitchers (the people who throw the ball) will likely boost the team's performance. Yet, he is concerned about money, as he heard left-handed pitchers have historically earned more!
#
# He tasked you to investigate this "sinister" issue and gave you some openly available data on the birthplace of this beautiful, dynamic sport --- the US.
#
# **About the homework.** This homework consists of four tasks. In Task 0, you will familiarize yourself with the rules of baseball. In Task 1, you will process the data, getting it ready for analysis. In Task 2, you will analyze the data to answer Mr. Russo’s question. Lastly, in Task 3, you will conduct additional analyses that consider the longitudinal nature of the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import YouTubeVideo

# %% [markdown]
# # Task 0 (Ungraded): Baseball 101
#
# **0.1 —** Familiarize yourself with the data; we won't explain the data in-depth in this notebook. Instead, you should take your time to read the readme.txt file inside the data folder. Note that this data is available on [GitHub](https://github.com/chadwickbureau/baseballdatabank).
#
# **0.2 —** Familiarize yourself with basic baseball rules. We will explain everything you need to know, but it will be helpful to get a basic understanding of it. Watching the video below should be enough! (Also available [here](https://www.youtube.com/watch?v=WMA8L5OpuDY).)
#
# A couple of useful things to remember:
# - **Pitchers** (try to) throw the ball
# - **Batters** (try to) hit the ball with the bat
# - **Catchers** (try to) catch the ball.

# %%
YouTubeVideo('WMA8L5OpuDY', width=800, height=300)

# %% [markdown]
# ---
#
# # Task 1 (16 pts): Get to Know Your Data
#
# As a good data scientist, you first load the data and perform some small sanity checks on it.
#
# 1. You are expected to continuously alter your dataframe as you complete the tasks. E.g., if you are asked to filter the data in a specific task, continue using the filtered dataset in the subsequent tasks.
# 2. When we tell you to "print the dataframe," make sure you print it in a way that shows the total number of rows and columns in it (`display(df)` should suffice).
#
# ---

# %% [markdown]
# **1.1 —** Load the `People`, `Salaries`, and `Pitching` dataframes. Then:
# - Filter the `Salaries`, and `Pitching` dataframes to remove all data after the year 2010.
# - For the `Salaries` dataframe drop all duplicate salaries for players in a given year. In other words, if a player (uniquely identified by `PlayerID`) has multiple salaries in a year (`yearID`), keep the first occurence in the dataframe and drop the remaining.
# - Calculate the size of each dataframe.
#
# Make [deep copies](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html) of all dataframes as you filter them.
#
# Hints:
# - 2007 should be included in the data.
# - 2010 should be included in the data.
# - 2011 should not be included in the data.

# %% [markdown]
# **Load the data**

# %%
data_folder = './data/baseballdatabank-2023/'
core_data_folder = f'{data_folder}core/'
contrib_data_folder = f'{data_folder}contrib/'
people = pd.read_csv(f'{core_data_folder}People.csv', sep=',', index_col='playerID')
salaries = pd.read_csv(f'{contrib_data_folder}Salaries.csv', sep=',')
pitching = pd.read_csv(f'{core_data_folder}Pitching.csv', sep=',')

# %% [markdown]
# **Filter Salaries and Pitching**

# %%
LAST_YEAR = 2010
salaries_before_2011 = salaries.query('yearID <= @LAST_YEAR').copy()
pitching_before_2011 = pitching.query('yearID <= @LAST_YEAR').copy()

# %% [markdown]
# **Filter duplicate salaries**

# %%
salaries_before_2011.drop_duplicates(subset=["playerID", "yearID"], keep="first", inplace=True)

# %% [markdown]
# **Sizes of dataframes**

# %%
print(f'Shape/Size of people: {people.shape} / {people.size}')
print(f'Shape/Size of pitching before 2011: {pitching_before_2011.shape} / {pitching_before_2011.size}')
print(f'Shape/Size of unique salaries for players per year: {salaries_before_2011.shape} / {salaries_before_2011.size}')
# Out:
# Shape/Size of people: (20676, 23) / 475548
# Shape/Size of pitching before 2011: (40433, 30) / 1212990
# Shape/Size of unique salaries for players per year: (21351, 5) / 106755

# %% [markdown]
# **1.2 —** The `throws` column in the `People` dataframe indicates, for each player, whether they throw with the left ("L") or right hand ("R"). Check what values are in the column and drop rows containing any value that is not "L" or "R," again, make a deep copy when you filter the dataframe.
#
# Hint: Remember NaNs!

# %% [markdown]
# **Explore values that are not "L" or "R"**

# %%
people.throws[people.throws.apply(lambda x: (x != 'R') & (x != 'L'))].unique()
# Out:
# array([nan, 'S'], dtype=object)

# %% [markdown]
# We can see from the previous code, that in addition to *R* and *L*, the *throws* column contains *NaN* and *S* as well.
#
# So we will drop all the *S*, as well as all the *NaN*

# %%
people_L_R = people[people["throws"].isin(["L", "R"])].copy()

# %% [markdown]
# **1.3 —** Merge the `People` dataframe with the `Pitching` dataframe. Your merge should populate the pitching data with statistics about the players. Print the resulting dataframe.

# %%
pitching_people = pd.merge(left=pitching_before_2011, right=people_L_R, how='left', on='playerID')
display(pitching_people)
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  \
# 0      bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...
# 1      brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...
# 2      fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...
# 3      fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...
# 4      fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...
# 40428  zambrca01    2010      1    CHN   NL  11   6  36  20   0  ...
# 40429  zieglbr01    2010      1    OAK   AL   3   7  64   0   0  ...
# 40430  zimmejo02    2010      1    WAS   NL   1   2   7   7   0  ...
# 40431   zitoba01    2010      1    SFN   NL   9  14  34  33   1  ...
# 40432  zumayjo01    2010      1    DET   AL   2   1  31   0   0  ...
#
#          nameLast        nameGiven  weight  height  bats  throws       debut  \
# ...

# %% [markdown]
# **1.4 —** You realize some of the data for the `throws` column is missing! Estimate the percentage of missing data points per year in that column, and show your estimates in a line plot. Additionally, print what percentage of the data was missing in 1892.

# %% [markdown]
# **Computing missing data**

# %%
throws_by_year = pitching_people[['yearID', 'throws']].groupby('yearID')
percentage_missing_throws_per_year = throws_by_year.agg(lambda x: x.isna().sum() / len(x) * 100)

# %% [markdown]
# **Defining plot range**
#
# *Note: range will be used in our second graph in the plot below to show insightful data*

# %%
year_range = percentage_missing_throws_per_year.query('throws != 0.0').index
year_min, year_max = year_range.min(), year_range.max()

# %% [markdown]
# **Plotting the missing data.**
#
# *Note: For the second graph, we stop at the year 1920 because all following years have 0% missing data.*

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

# First graph, full range
ax[0].plot(percentage_missing_throws_per_year)
ax[0].set_title('Percentage of missing throws data per year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Percentage missing throws data [%]')

# Second graph, relevant range
ax[1].plot(percentage_missing_throws_per_year)
ax[1].set_xlim(year_min, year_max + 3)
ax[1].set_title('Insight of relevant data')
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Percentage missing throws data [%]')

plt.show()

# Answer to the asked question
print(f'{percentage_missing_throws_per_year.loc[1892, "throws"]:.3f}% of the throws data were missing in 1892.')
# Out:
# 4.545% of the throws data were missing in 1892.

# %% [markdown]
# **1.5 —** Filter the dataset you just merged (hereinafter `Pitching-People`) to just contain data from after 1920 (with 1920 included). Do the same with the `Salaries` dataset. Make deep copies of both dataframes as you filter them.

# %%
FIRST_YEAR = 1920
pitching_people_between_1920_2010 = pitching_people.query('yearID >= @FIRST_YEAR').copy()
salaries_between_1920_2010 = salaries_before_2011.query('yearID >= @FIRST_YEAR').copy()

# %% [markdown]
# **1.6 —**  Merge the `Pitching-People` dataframe with the `Salaries` dataframe. Your merge should populate the `Pitching-People` dataframe with statistics about the pitchers'salaries across the years. Note that the `Salaries` dataframe contains the salary **per year.** Print the resulting dataframe.

# %%
pitching_people_salaries = pd.merge(left=pitching_people_between_1920_2010, right=salaries_between_1920_2010,
                                    how='left', on=['playerID', 'yearID'])
display(pitching_people_salaries)
# Out:
#         playerID  yearID  stint teamID_x lgID_x   W   L   G  GS  CG  ...  \
# 0      acostjo01    1920      1      WS1     AL   5   4  17   5   4  ...
# 1      adamsba01    1920      1      PIT     NL  17  13  35  33  19  ...
# 2      alexape01    1920      1      CHN     NL  27  14  46  40  33  ...
# 3      altener01    1920      1      DET     AL   0   1  14   1   0  ...
# 4      ayersdo01    1920      1      DET     AL   7  14  46  23   8  ...
# ...          ...     ...    ...      ...    ...  ..  ..  ..  ..  ..  ...
# 33876  zambrca01    2010      1      CHN     NL  11   6  36  20   0  ...
# 33877  zieglbr01    2010      1      OAK     AL   3   7  64   0   0  ...
# 33878  zimmejo02    2010      1      WAS     NL   1   2   7   7   0  ...
# 33879   zitoba01    2010      1      SFN     NL   9  14  34  33   1  ...
# 33880  zumayjo01    2010      1      DET     AL   2   1  31   0   0  ...
#
#        height  bats  throws       debut   finalGame   retroID    bbrefID  \
# ...

# %% [markdown]
# We only merged on 'playerID' and 'yearID', to be consistent with the choice of filtering the salary table to keep the first entry only for each player per year. We could have merged it using 'playerID', 'yearID', 'teamID', and 'lgID'. The latter would have increased the percentage of missing data for the task $1.7$.

# %% [markdown]
# **1.7 —** You realize some of the data for the `salary` column is missing! Estimate the percentage of missing data points per year, and show your estimates in a line plot. Additionally, print what percentage of the data was missing in 2002.

# %% [markdown]
# **Computing missing data**

# %%
pitching_people_salaries_per_year = pitching_people_salaries[['yearID', 'salary']].groupby('yearID')
percentage_missing_salaries_per_year = pitching_people_salaries_per_year.agg(lambda x: x.isna().sum() / len(x) * 100)

# %% [markdown]
# **Defining plot range**
#
# *Note: range will be used in our second graph in the plot below to show insightful data*

# %%
year_range = percentage_missing_salaries_per_year.query('salary != 100.0').index
year_min, year_max = year_range.min(), year_range.max()

# %% [markdown]
# **Plotting the missing data.**
#
# *Note: For the second graph, we start at the year 1980 because all previous years have 100% missing data.*

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

# First axes, full range
ax[0].plot(percentage_missing_salaries_per_year)
ax[0].set_title('Percentage missing salaries data per year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Percentage missing data [%]')

# Second axes, relevant range
ax[1].plot(percentage_missing_salaries_per_year)
ax[1].set_title('Insight of relevant data')
ax[1].set_xlim(year_min, year_max)
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Percentage missing data [%]')

plt.show()

# Answer to asked question
print(f'{percentage_missing_salaries_per_year.loc[2002, "salary"]:.3f}% of the salaries data were missing in 2002.')
# Out:
# 36.267% of the salaries data were missing in 2002.

# %% [markdown]
# If merging in task $1.6$ would have been on the four mentioned features, we would have obtained a missing salary percentage of $41.882\%$.

# %% [markdown]
# **1.8 —** Find and print the first and last year for which there exists any salary data. Filter the resulting, merged dataframe to include only data between these two dates. Again make sure you make a deep copy of the dataframe, and print the resulting dataframe.

# %% [markdown]
# **Find the first and last year**

# %%
# Filter out NaN from salaries to only have rows for which there is a salary
non_nan_salaries = pitching_people_salaries.dropna(subset=['salary'])

# Return the smallest year and the biggest year.
[min_year, max_year] = non_nan_salaries.yearID.agg([min, max])
print(f'The first year for which there is salary information is {min_year}.\n'
      f'The last year for which there is salary information is {max_year}.')
# Out:
# The first year for which there is salary information is 1985.
# The last year for which there is salary information is 2010.

# %% [markdown]
# **Filter dataframe to include only data between these two dates**

# %%
pitching_people_salaries_existing_salaries = pitching_people_salaries.query(
    '@min_year <= yearID & yearID <= @max_year').copy()
display(pitching_people_salaries_existing_salaries)
# Out:
#         playerID  yearID  stint teamID_x lgID_x   W   L   G  GS  CG  ...  \
# 18432   aasedo01    1985      1      BAL     AL  10   6  54   0   0  ...
# 18433  abregjo01    1985      1      CHN     NL   1   1   6   5   0  ...
# 18434  ackerji01    1985      1      TOR     AL   7   2  61   0   0  ...
# 18435  agostju01    1985      1      CHA     AL   4   3  54   0   0  ...
# 18436  aguilri01    1985      1      NYN     NL  10   7  21  19   2  ...
# ...          ...     ...    ...      ...    ...  ..  ..  ..  ..  ..  ...
# 33876  zambrca01    2010      1      CHN     NL  11   6  36  20   0  ...
# 33877  zieglbr01    2010      1      OAK     AL   3   7  64   0   0  ...
# 33878  zimmejo02    2010      1      WAS     NL   1   2   7   7   0  ...
# 33879   zitoba01    2010      1      SFN     NL   9  14  34  33   1  ...
# 33880  zumayjo01    2010      1      DET     AL   2   1  31   0   0  ...
#
#        height  bats  throws       debut   finalGame   retroID    bbrefID  \
# ...

# %% [markdown]
# ---
#
# # Task 2 (16 pts)
#
# Task 1, was a softball? Huh? For Task 2, you will use a dataset similar to what you obtained at the end of Task 1. This code loads it.

# %%
# PROVIDED CODE

df = pd.read_csv("./data/dataset-task-2.csv")
df.head()
# Out:
#     playerID  yearID  stint teamID lgID  W  L   G  GS  CG  ...  \
# 0  prietar01    1998      1    OAK   AL  0  1   2   2   0  ...
# 1  pooleji02    2000      1    DET   AL  1  0  18   0   0  ...
# 2    leecl02    2007      1    CLE   AL  5  8  20  16   1  ...
# 3  purceda01    2010      1    TOR   AL  1  1  33   0   0  ...
# 4  gundeer01    1992      1    SEA   AL  2  1   9   0   0  ...
#
#         nameGiven  weight  height  bats  throws       debut   finalGame  \
# 0           Ariel   220.0    75.0     R       R  1995-07-02  2001-05-10
# 1   James Richard   190.0    74.0     L       L  1990-06-15  2000-06-01
# 2  Clifton Phifer   205.0    75.0     L       L  2002-09-15  2014-07-31
# 3      David Kent   245.0    77.0     L       L  2008-04-18  2013-09-20
# 4     Eric Andrew   175.0    72.0     R       L  1990-04-11  2000-05-17
#
#     retroID    bbrefID     salary
# 0  priea001  prietar01        NaN
# 1  poolj001  pooleji02   200000.0
# 2  lee-c003    leecl02  3000000.0
# ...

# %% [markdown]
# Some comments about this dataset:
# - This is a sample of the dataset obtained in Task 1.
# - Even if you  did everything correctly for Task 1, this dataframe would contain a different number of rows --- as it is a sample.
# - This prevent that mistakes made in Task 1 cascade into Tasks 2 and 3.
#
#
# With this data, you will proceed to investigate differences in the salaries and performance of left-handed and right-handed pitchers.
#
# ---

# %% [markdown]
# **2.1 —** Plot the Complementary cumulative distribution function (CCDF) of salary for left-handed and right-handed athletes. Consider data from all years.

# %%
# We import seaborn to be able to use ecdfplot function to draw easily the plot
import seaborn as sn

df_salary_throws = df[['salary', 'throws']].copy()

# Divide by 1 million for visibility reason
df_salary_throws.salary = df_salary_throws.salary / 1e6

# Filter out nan values
df_salary_throws.dropna(subset='salary', inplace=True)

# Plot
sn.ecdfplot(df_salary_throws, x='salary', hue='throws', complementary=True)
plt.legend(loc='upper right', labels=['Right-handed', 'Left-handed'])
plt.title('CCDF of salaries left and right handed athletes')
plt.ylabel('CCDF of salaries')
plt.xlabel('Salary in million')

plt.show()

# %% [markdown]
# **2.2 —** /Discuss:/ This plot has an issue which severely limits the amount of information one can draw from it. Describe the issue and propose a solution to address it.

# %% [markdown]
# The problem with this distribution is that it is heavy-tailed, and it is hard to read information on it.
# The problem was to determine if it would be more expensive to hire left-handed pitchers than right-handed ones. That is why we could use a log axis to address this problem and reveal high salary information.

# %% [markdown]
# **2.3 —** Implement the solution proposed by yourself in the previous question.

# %%
# Plot, note that we use the log on the y-axis as it is the one that reveals the most information about the tail
sn.ecdfplot(df_salary_throws, x='salary', hue='throws', complementary=True, log_scale=(False, True))
plt.title('CCDF of salaries left and right handed athletes')
plt.legend(loc='upper right', labels=['Right-handed', 'Left-handed'])
plt.ylabel('CCDF of salaries (log-scale)')
plt.xlabel('Salary in million')

plt.show()

# %% [markdown]
# **2.4 —** /Discuss:/ Considering this second version of the plot, describe what the plot shows with regard to the distribution of salaries from left- and right-handed pitchers.

# %% [markdown]
# From the CCDF, we can see that the proportion of right-handed pitchers earning less than 12.5M is higher than the proportion of left-handed ones. Conversely, the proportion of right-handed pitchers earning more than 12.5M is lower than the proportion of left-handed ones. As we can see on the graph the most paid left-handed pitchers is more paid than its right counterpart.

# %% [markdown]
# **2.5—** Calculate the mean and the 95% confidence interval for the salary of left-handed and right-handed pitchers aggregating data across all years. Print the estimates. Additionally, present the estimates and the confidence intervals in a [point plot](https://seaborn.pydata.org/_images/pointplot_7_0.png). Calculate your confidence intervals using the standard error of the mean and ignoring missing values.

# %% [markdown]
# **Scipy method**
#
# As requested, we first compute the estimates of mean and 95% confidence interval using parametric method (using standard error of the mean).

# %%
import scipy.stats as st

# Split again the left and right-handed and focus on salaries
left_handed = df_salary_throws.query('throws == "L"').salary.copy()
right_handed = df_salary_throws.query('throws == "R"').salary.copy()

# Compute the means and standard deviation of both categories
[mean_salary_L, std_salary_L] = left_handed.agg(['mean', 'std'])
[mean_salary_R, std_salary_R] = right_handed.agg(['mean', 'std'])

# Calculate confidence interval using normal distribution with scipy library 
cf_mean_salary_L_inf, cf_mean_salary_L_sup = st.norm.interval(confidence=0.95, loc=mean_salary_L,
                                                              scale=std_salary_L / np.sqrt(len(left_handed)))
cf_mean_salary_R_inf, cf_mean_salary_R_sup = st.norm.interval(confidence=0.95, loc=mean_salary_R,
                                                              scale=std_salary_R / np.sqrt(len(right_handed)))

# %% [markdown]
# **Bootstrap method**
#
# Then we compute once again those values, using non-parametric method, to compare it to a parametric method. Also, *bootstrap* allows us to display the estimated distribution of the mean salary, letting us confirm the hypotheses from central limit theorem, that the mean of salaries follows (nearly) a normal distribution.

# %%
# Compute the 95% confidence interval using bootstrap
n_bootstraps = 10000

# Left-handed
bootstrap_samples_left = [np.random.choice(left_handed, left_handed.shape[0]) for _ in range(n_bootstraps)]
bootstrap_means_left = [sample.mean() for sample in bootstrap_samples_left]
confidence_interval_left = np.percentile(bootstrap_means_left, [2.5, 97.5])

# Right-handed
bootstrap_samples_right = [np.random.choice(right_handed, right_handed.shape[0]) for _ in range(n_bootstraps)]
bootstrap_means_right = [sample.mean() for sample in bootstrap_samples_right]
confidence_interval_right = np.percentile(bootstrap_means_right, [2.5, 97.5])

# Create subplots
fig, ax = plt.subplots(1, 3, figsize=(12, 4), constrained_layout=True)

# Create a new figure and axes for the left-handed plot
sn.histplot(bootstrap_means_left, kde=True, ax=ax[0])
ax[0].set_title("Bootstrapped Means - Left-handed")
ax[0].set_xlabel("Mean in millions")

# Display the 95% confidence interval
ax[0].axvline(confidence_interval_left[0], color='red', linestyle='--', label='2.5th percentile')
ax[0].axvline(confidence_interval_left[1], color='blue', linestyle='--', label='97.5th percentile')
ax[0].legend()

# Create a new figure and axes for the right-handed plot
sn.histplot(bootstrap_means_right, kde=True, ax=ax[1])
ax[1].set_title("Bootstrapped Means - Right-handed")
ax[1].set_xlabel("Mean in millions")

# Display the 95% confidence interval
ax[1].axvline(confidence_interval_right[0], color='red', linestyle='--', label='2.5th percentile')
ax[1].axvline(confidence_interval_right[1], color='blue', linestyle='--', label='97.5th percentile')
ax[1].legend()

# Print confidence interval of both methods
print('Scipy methods:\n==========================')
print(
    f'\tThe mean of the left-handed salary is ${mean_salary_L:.3f}M, with a 95% confidence interval of [${cf_mean_salary_L_inf:.3f}M, ${cf_mean_salary_L_sup:.3f}M]')
print(
    f'\tThe mean of the right-handed salary is ${mean_salary_R:.3f}M, with a 95% confidence interval of [${cf_mean_salary_R_inf:.3f}M, ${cf_mean_salary_R_sup:.3f}M]')
print('\nBootstrap methods:\n==========================')
print(
    f'\tThe mean of the left-handed salary is ${mean_salary_L:.3f}M, with a 95% confidence interval of [${confidence_interval_left[0]:.3f}M, ${confidence_interval_left[1]:.3f}M]')
print(
    f'\tThe mean of the right-handed salary is ${mean_salary_R:.3f}M, with a 95% confidence interval of [${confidence_interval_right[0]:.3f}M, ${confidence_interval_right[1]:.3f}M]')

sn.pointplot(x="throws", y="salary", data=df_salary_throws, errorbar=('ci', 95), ax=ax[2])
ax[2].set_xlabel("Handedness")
ax[2].set_ylabel("Salary in millions")
ax[2].set_title("Mean salary of left-handed and right-handed pitchers")
ax[2].axhline(confidence_interval_left[1], linestyle='--', color='red')
ax[2].axhline(confidence_interval_right[0], linestyle='--', color='red')
plt.show()
# Out:
# Scipy methods:
# ...
# 	The mean of the left-handed salary is $1.437M, with a 95% confidence interval of [$1.353M, $1.522M]
# 	The mean of the right-handed salary is $1.597M, with a 95% confidence interval of [$1.540M, $1.655M]
#
# Bootstrap methods:
# ...
# 	The mean of the left-handed salary is $1.437M, with a 95% confidence interval of [$1.355M, $1.523M]
# 	The mean of the right-handed salary is $1.597M, with a 95% confidence interval of [$1.539M, $1.654M]

# %% [markdown]
# As we can see both methods produce very similar results. As expected the mean salary distribution nearly follows a normal distribution.
#
# Notes that we are aware that the bootstrap method was not asked to be computed, but as we wanted to compare and verify the results of both methods we printed/plotted results of each of scipy and bootstrap methods.

# %% [markdown]
# **2.6 —** /Discuss:/ Can you tell whether the difference between the two distributions is statistically significant (at the .05 level of significance) from the image? Why?

# %% [markdown]
# Since the confidence intervals don't overlap, the difference of both means is statistically significant (at the 0.5 level of significance). We can strongly believe that there is a difference between handedness in salaries.

# %% [markdown]
# **2.7 —** Perform a t-test test comparing the salaries of left-handed and right-handed pitchers at the .05 level of significance. Consider data from all years. /Discuss:/ Who earns more?

# %%
ttest = st.ttest_ind(right_handed, left_handed, equal_var=False)

print('\nt-test result:\n==========================')
print(f'\tt-statistic: {ttest[0]:.3f},\n'
      f'\tp-value: {ttest[1]:.5f}')
# Out:
# t-test result:
# ...
# 	t-statistic: 3.061,
# 	p-value: 0.00221

# %% [markdown]
# As the t-statistic is equal to $3.061$ and is positive, the mean of the salary from right-handed athletes is probably higher than the mean from left-handed athletes. The null hypothesis $H_0$ that both populations have the same mean can be rejected, as the p-value is equal to $0.00221 < 0.05$. We can therefore be statistically confident that both means are different.

# %% [markdown]
# ---
#
# Now, let's turn to analyzing performance. A commonly used metric to evaluate the skill of a pitcher is to look at the batting average of the pitcher’s opponents. According to [Wikipedia](https://en.wikipedia.org/wiki/Batting_average_against),
#
# > In baseball statistics, batting average against (denoted by BAA or AVG), also known as opponents' batting average (denoted by OBA), is a statistic that measures a pitcher's ability to prevent hits during official at bats. It can alternatively be described as the league's hitters' combined batting average against the pitcher.
#
# The intuition is clear: if you are a pitcher, you do not want the batter actually to hit the ball. Thus, if you are a good pitcher, the opponent batter should miss a lot against you! Conveniently, this is already calculated on a yearly basis in our data.
#
# ---

# %% [markdown]
# **2.8 —** Considering data from all years, calculate the mean opponents' batting average for left- and right-handed pitchers. Run a t-test test to determine if this difference is statistically significant at the .05 level of significance. **Consider only pitchers in the years during which they have played atleast 5 games.** /Discuss:/ According to this approach, who are the better pitchers? Left-handed or right-handed pitchers?

# %%
# Split again the left and right-handed and focus on the opponents' batting average
MIN_NB_GAME = 5
df_baopp_throws = df.query('G >= @MIN_NB_GAME')[['BAOpp', 'throws']].copy()  #select only pitcher with at least 5 games
df_baopp_throws.dropna(subset='BAOpp', inplace=True)  # filter out nan values
df_baopp_throws_L = df_baopp_throws[df_baopp_throws.throws == 'L'].BAOpp.copy()
df_baopp_throws_R = df_baopp_throws[df_baopp_throws.throws == 'R'].BAOpp.copy()

# Compute the means and standard deviation of both categories
[mean_L, std_L] = df_baopp_throws_L.agg(['mean', 'std'])
[mean_R, std_R] = df_baopp_throws_R.agg(['mean', 'std'])

# Calculate confidence interval using normal distribution with scipy library 
cf_mean_baopp_throws_L_inf, cf_mean_baopp_throws_L_sup = st.norm.interval(confidence=0.95, loc=mean_L,
                                                              scale=std_L / np.sqrt(len(df_baopp_throws_L)))
cf_mean_baopp_throws_R_inf, cf_mean_baopp_throws_R_sup = st.norm.interval(confidence=0.95, loc=mean_R,
                                                              scale=std_R / np.sqrt(len(df_baopp_throws_R)))

# Print means and confidence interval
print("Mean opponents' batting average:\n==========================")
print(
    f"\tMean left-handed pitchers: {mean_L:.4f}, with a 95% confidence interval of [{cf_mean_baopp_throws_L_inf:.4f}, {cf_mean_baopp_throws_L_sup:.4f}]")
print(
    f"\tMean right-handed pitchers: {mean_R:.4f}, with a 95% confidence interval of [{cf_mean_baopp_throws_R_inf:.4f}, {cf_mean_baopp_throws_R_sup:.4f}]")

# Compute and print t-test
ttest = st.ttest_ind(df_baopp_throws_L, df_baopp_throws_R, equal_var=False)
print('\nt-test result:\n==========================')
print(f'\tt-statistic: {ttest[0]:.3f},\n'
      f'\tp-value: {ttest[1]:.5f}')
# Out:
# Mean opponents' batting average:
# ...
# 	Mean left-handed pitchers: 0.2704, with a 95% confidence interval of [0.2688, 0.2720]
# 	Mean right-handed pitchers: 0.2678, with a 95% confidence interval of [0.2669, 0.2688]
#
# t-test result:
# ...
# 	t-statistic: 2.649,
# 	p-value: 0.00810

# %% [markdown]
# The pitchers with the highest average are the left-handed pitchers. As the p-value is $0.00810$ which is smaller than $0.05$, we can reject the null hypothesis $H_0$ that both population means are the same. We can therefore be statistically confident that both means are different.
#
# In conclusion, the right-handed pitchers are slightly better on average.

# %% [markdown]
# # Task 3 (18 pts)
#
# Before you report your results to Mr. Russo, you decide to run them by your favorite Applied Data Analysis' TA, Ms. Sakota. She seems skeptical! According to her, you should take into account the time variable!

# %% [markdown]
# **3.1 —** Repeat the analysis from tasks 2.7 and 2.8 considering only data from the year 2000. That is, use a t-test to determine the distribution of salaries (2.7) and opponents' batting average (2.8) for all data of the year 2000 only.

# %% [markdown]
# **t-test on salary distribution for the year 2000**

# %%
# Split again the left and right-handed and focus on salaries and the year 2000
YEAR_2000 = 2000
df_salary_throws_2000 = df.query('yearID == @YEAR_2000')[['salary', 'throws']].copy()
df_salary_throws_2000.dropna(subset='salary', inplace=True)  # filter out nan values

# Divide by 1 million for visibility reason
df_salary_throws_2000.salary = df_salary_throws_2000.salary / 1e6
df_salary_throws_2000_L = df_salary_throws_2000.query('throws == "L"').salary
df_salary_throws_2000_R = df_salary_throws_2000.query('throws == "R"').salary

# Compute the means and standard deviation of both categories
[mean_L, std_L] = df_salary_throws_2000_L.agg(['mean', 'std'])
[mean_R, std_R] = df_salary_throws_2000_R.agg(['mean', 'std'])

# Calculate confidence interval using normal distribution with scipy library 
cf_mean_salary_L_2000_inf, cf_mean_salary_L_2000_sup = st.norm.interval(confidence=0.95, loc=mean_L,
                                                              scale=std_L / np.sqrt(len(df_salary_throws_2000_L)))
cf_mean_salary_R_2000_inf, cf_mean_salary_R_2000_sup = st.norm.interval(confidence=0.95, loc=mean_R,
                                                              scale=std_R / np.sqrt(len(df_salary_throws_2000_R)))

# Print means and confidence interval
print("Mean opponents' batting average:\n==========================")
print(
    f"\tMean left-handed pitchers: ${mean_L:.4f}M, with a 95% confidence interval of [${cf_mean_salary_L_2000_inf:.4f}M, ${cf_mean_salary_L_2000_sup:.4f}M]")
print(
    f"\tMean right-handed pitchers: ${mean_R:.4f}M, with a 95% confidence interval of [${cf_mean_salary_R_2000_inf:.4f}M, ${cf_mean_salary_R_2000_sup:.4f}M]")

# Compute and print t-test
ttest = st.ttest_ind(df_salary_throws_2000_R, df_salary_throws_2000_L, equal_var=False)
print('\nt-test result:\n==========================')
print(f'\tt-statistic: {ttest[0]:.4f},\n'
      f'\tp-value: {ttest[1]:.5f}')
# Out:
# Mean opponents' batting average:
# ...
# 	Mean left-handed pitchers: $1.7448M, with a 95% confidence interval of [$1.3097M, $2.1798M]
# 	Mean right-handed pitchers: $1.8393M, with a 95% confidence interval of [$1.5794M, $2.0992M]
#
# t-test result:
# ...
# 	t-statistic: 0.3656,
# 	p-value: 0.71505

# %% [markdown]
# As the p-value $0.71505$ is greater than $0.05$, the null hypothesis $H_0$ that both populations have the same mean **cannot** be rejected. There is insufficient evidence at the $\alpha = 0.05$ significance level to conclude that the average salary of the right-handed athletes is significantly different than the one from the left-handed athletes.

# %% [markdown]
# **t-test on opponents' batting average**

# %%
df_baopp_throws_2000 = df.query('G >= @MIN_NB_GAME & yearID == @YEAR_2000')[['BAOpp', 'throws']].copy()
df_baopp_throws_2000.dropna(subset='BAOpp', inplace=True)

df_baopp_throws_2000_L = df_baopp_throws_2000.query('throws == "L"').BAOpp
df_baopp_throws_2000_R = df_baopp_throws_2000.query('throws == "R"').BAOpp

# Compute the means and standard deviation of both categories
[mean_L, std_L] = df_baopp_throws_2000_L.agg(['mean', 'std'])
[mean_R, std_R] = df_baopp_throws_2000_R.agg(['mean', 'std'])

# Calculate confidence interval using normal distribution with scipy library 
cf_mean_baopp_throws_L_2000_inf, cf_mean_baopp_throws_L_2000_sup = st.norm.interval(confidence=0.95, loc=mean_L,
                                                                          scale=std_L / np.sqrt(len(df_baopp_throws_2000_L)))
cf_mean_baopp_throws_R_2000_inf, cf_mean_baopp_throws_R_2000_sup = st.norm.interval(confidence=0.95, loc=mean_R,
                                                              scale=std_R / np.sqrt(len(df_baopp_throws_2000_R)))

# Print means and confidence interval
print("Mean opponents' batting average:\n==========================")
print(
    f"\tMean left-handed pitchers: {mean_L:.4f}, with a 95% confidence interval of [{cf_mean_baopp_throws_L_2000_inf:.4f}, {cf_mean_baopp_throws_L_2000_sup:.4f}]")
print(
    f"\tMean right-handed pitchers: {mean_R:.4f}, with a 95% confidence interval of [{cf_mean_baopp_throws_R_2000_inf:.4f}, {cf_mean_baopp_throws_R_2000_sup:.4f}]")

# Compute and print t-test
ttest = st.ttest_ind(df_baopp_throws_2000_L, df_baopp_throws_2000_R, equal_var=False)
print('\nt-test result:\n==========================')
print(f'\tt-statistic: {ttest[0]:.4f},\n'
      f'\tp-value: {ttest[1]:.5f}')
# Out:
# Mean opponents' batting average:
# ...
# 	Mean left-handed pitchers: 0.2774, with a 95% confidence interval of [0.2675, 0.2872]
# 	Mean right-handed pitchers: 0.2765, with a 95% confidence interval of [0.2720, 0.2810]
#
# t-test result:
# ...
# 	t-statistic: 0.1567,
# 	p-value: 0.87565

# %% [markdown]
# As the p-value $0.87565$ is greater than $0.05$, the null hypothesis $H_0$ that both populations have the same opponents' batting average mean cannot be rejected. There is insufficient statistical evidence at the $\alpha = 0.05$ significance level to conclude that the average opponents' batting average of the left-handed pitcher is significantly different from the one of the right-handed pitcher.

# %% [markdown]
# **3.2 —** Create a single plot with 14 inches of width and 4 inches of height. The plot should contain three panels:
# - Panel A: The percentage of left-handed pitchers per year;
# - Panel B: The average salary of all pitchers per year
# - Panel C: The average opponents' batting average of all pitchers per year.
#
# Additionally, print, for the year 2007:
# - the percentage of left-handed pitchers.
# - the average salary.
# - the average  opponents' batting average.

# %% [markdown]
# **Calculate the required data to plot**

# %%
# Calculate the percentage of left-handed pitchers per year
percentage_left_handed_by_year = df[['throws', 'yearID']].groupby('yearID').apply(
    lambda x: len(x[x.throws == 'L']) / len(x) * 100)

# Calculate the average salary of all pitchers per year
average_salary_by_year = df[['yearID', 'salary']].groupby('yearID').mean().salary.copy()
# For clarity reason
average_salary_by_year = average_salary_by_year/1e6 

# Calculate the average opponents' batting average of all pitchers per year
average_opponents_batting_average = df[['yearID', 'BAOpp']].groupby('yearID').mean().BAOpp

# %% [markdown]
# **Plot of data**

# %%
fig, ax = plt.subplots(1, 3, figsize=(14, 4), constrained_layout=True)
# Panel A
ax[0].plot(percentage_left_handed_by_year)
ax[0].set_title('Percentage of left-handed pitchers per year')
ax[0].set_xlabel('Years')
ax[0].set_ylabel('Percentage of left-handed pitchers (%)')

# Panel B
ax[1].plot(average_salary_by_year)
ax[1].set_title('Average salary of pitchers per year')
ax[1].set_xlabel('Years')
ax[1].set_ylabel('Average salary in millions')

# Panel C
ax[2].plot(average_opponents_batting_average)
ax[2].set_title("Average opponents' batting average of pitchers per year")
ax[2].set_xlabel('Years')
ax[2].set_ylabel("Average opponents' batting average")
plt.show()

# %% [markdown]
# **Values for the year 2007**

# %%
YEAR_2007 = 2007
print(f'The percentage of left-handed pitchers for 2007 was: {percentage_left_handed_by_year[YEAR_2007]:.3f}%.')
print(f'The average salary of all pitchers for 2007 was: ${average_salary_by_year[YEAR_2007]:.3f}M.')
print(f"The average of the opponents' batting average for 2007 was: {average_opponents_batting_average[YEAR_2007]:.3f}.")
# Out:
# The percentage of left-handed pitchers for 2007 was: 28.161%.
# The average salary of all pitchers for 2007 was: $2.601M.
# The average of the opponents' batting average for 2007 was: 0.279.

# %% [markdown]
# **3.3 —** Create a single plot with 10 inches of width and 4 inches of height. The plot should contain two panels:
# - Panel A: The average salary for left and right-handed pitchers per year, show 95% confidence intervals in your plot.
# - Panel B: The average opponents' batting average for left and right-handed pitchers across the years, show 95% confidence intervals in your plot.
#
#
# Additionally, print, for the year 1999:
# - the average salary of left-handed pitchers.
# - the average opponents' batting average of right-handed pitchers.

# %% [markdown]
# **Plot of data**

# %%
# Used to remove irrelevant warnings
import warnings
warnings.filterwarnings("ignore")

fig, ax = plt.subplots(1, 2, figsize=(10, 4), constrained_layout=True)

# Panel A
df_visualisation = df.copy()
df_visualisation.salary /= 1e6
sn.lineplot(df_visualisation, x='yearID', y='salary', hue='throws', errorbar=('ci', 95), err_style='band', ax=ax[0])
ax[0].set_title('Average salary for left and right-handed pitchers')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Average salary in millions')
ax[0].legend(loc='upper left', labels=['Right-handed', '_', 'Left-handed', '_'])

# Panel B
sn.lineplot(df, x='yearID', y='BAOpp', hue='throws', errorbar=('ci', 95), err_style='band', ax=ax[1])
ax[1].set_title("Average opponents batting average for left and right-handed pitchers'")
ax[1].set_xlabel('Year')
ax[1].set_ylabel("Average opponents' batting average")
ax[1].legend(loc='upper left', labels=['Right-handed', '_', 'Left-handed', '_'])
plt.show()

# %% [markdown]
# **Values for the year 1999**

# %%
YEAR_1999 = 1999
average_salary_by_year_L_R = df[['yearID', 'salary', 'throws']].groupby(['yearID', 'throws']).mean().salary

# For clarity reasons
average_salary_by_year_L_R /= 1e6
average_opponents_batting_average_l_R = df[['yearID', 'BAOpp', 'throws']].groupby(['yearID', 'throws']).mean().BAOpp

print(f'The average salary of a left-handed pitcher in 1999 was: ${average_salary_by_year_L_R[YEAR_1999, "L"]:.3f}M.')
print(
    f"The average of the opponents' batting average of a right-handed pitcher in 1999 was: {average_opponents_batting_average_l_R[YEAR_1999, 'R']:.3f}.")
# Out:
# The average salary of a left-handed pitcher in 1999 was: $1.273M.
# The average of the opponents' batting average of a right-handed pitcher in 1999 was: 0.286.

# %% [markdown]
# **3.4 —** /Discuss:/ Contrast the results obtained in Tasks 3.1 / 3.3 / 3.3 with the results obtained in Tasks 2.7 and 2.8. Are left-handed better than right-handed pitchers? Do they earn better salaries? Explain why the analysis might have reached different results.

# %% [markdown]
# During $Tasks\ 2.7$ and $2.8$, we conducted an analysis without accounting for the time component (years). Our initial conclusion was that there was statistical evidence indicating differences in mean salary and mean opponent batting average between right and left-handed pitchers. Specifically, right-handed pitchers appeared to be, on average, more proficient and higher-paid.
#
# In $Task\ 3.1$, $3.2$ and $3.3$, we introduced the time component. As a result, the outcomes differed, as no statistical evidence was found for each year regarding differences in mean salary and opponent batting average between right and left-handed pitchers at a 5% confidence level.
#
# As mentioned earlier, $Task\ 2$ and $Task\ 3$ differ in the time variable. This distinction may explain the varying results, as these analyses address different questions:
#
# - Task 2 answers the question: "Does a difference exist in mean salary and mean opponent batting average between right and left-handed pitchers over the years?"
# - Task 3 answers the question: "Does a difference exist in mean salary and mean opponent batting average between right and left-handed pitchers for each year?"
#
# Our client is interested in the answers provided by $Task\ 3$, as this allows us to determine if, for a specific season (i.e., a year), there is any noticeable difference in performance between left-handed and right-handed pitchers. Additionally, it helps determine whether they need to allocate a higher budget for a season with a left-handed pitcher compared to a right-handed one.

# %% [markdown]
# **3.5 —** Before showing the final results to Mr. Russo, you pass them by Ms. Sakota once more. She looks happier now, but still looks a bit concerned. She asks you to perform a sanity check on the missing data for the period you are considering. Specifically, she is worried that there are significantly more missing salaries for left-handed pitchers or for right-handed pitchers.
#
# - Create a plot with 10 inches of width and 4 inches of height. The plot should depict the fraction of missing salary  salary for left and right-handed pitchers per year, show 95% confidence intervals in your plot.
# - Print the fraction of left-handed pitchers with salary data missing for the year 2002.
# - /Discuss:/ According to the plot, are there significantly more missing salaries for left-handed pitchers?

# %% [markdown]
# **Plot of data**

# %%
df_salary_fill_dummy = df.copy()

# Fill NaN with dummy value to prevent na from being removed by seaborn, and be able to easily aggregate them in plot
df_salary_fill_dummy.salary = df_salary_fill_dummy.salary.fillna(-1)  

# Use subplots to be able to constraint the layout
fig, ax = plt.subplots(1, 1, figsize=(10, 4), constrained_layout=True)
sn.lineplot(df_salary_fill_dummy, x='yearID', y='salary', hue='throws', errorbar=('ci', 95), err_style='band',
            estimator=lambda x: len(x[x == -1]) / len(x) * 100, ax=ax)
ax.set_title('Fraction of missing salary for left and right-handed pitchers')
ax.set_xlabel('Year')
ax.set_ylabel('Missing salary (%)')
ax.legend(loc='upper center', labels=['Right-handed', '_', 'Left-handed', '_'])

plt.show()

# %% [markdown]
# Print the fraction of left-handed pitchers with salary data missing for the year 2002.

# %%
df_salary_nan_percentage = df[['yearID', 'salary', 'throws']].groupby(['yearID', 'throws']).agg(
    lambda x: x.isna().sum() / len(x) * 100).salary
print(f'The fraction of left-handed pitchers with missing salaries data: {df_salary_nan_percentage[2002, "L"]:.3f}%.')
# Out:
# The fraction of left-handed pitchers with missing salaries data: 38.172%.

# %% [markdown]
# **Discussion:**
#
# As the confidence intervals overlap all along, the differences in missing salaries between both right-handed and left-handed pitchers is not statistically significant at a $5\%$ significance level.

# %% [markdown]
# **3.6 –**  /Discuss:/ If 95% of the salaries of right-handed pitchers were missing and none for the left-handed pitchers, what problem could you envision could happen downstream when you analyzed the data?

# %% [markdown]
# If 95% of the right-handed pitchers' salaries were missing, and none of the left-handed pitchers, we would be unable to validate the sanity check conducted just above ($Task\ 3.5$).
#
# Indeed, left-handed mean curve for the fraction of missing salaries would never intersect with the right-handed mean curve and its 95% confidence interval. Please note that no CI is expected from missing values of left-handed pitchers, since there are no missing values at all.
#
# As a result, they would not meet the sanity check's criteria, which requires both categories of pitchers to exhibit statistical similarity in their percentage of missing values. In such a scenario, our results would lack statistical relevance, which would likely not meet Ms. Sakota's expectations.

# %% [markdown]
#  **Illustration sketch**

# %%
# We use code for this because markdown is not rendering properly on browser (https://github.com/jupyter/notebook/issues/3278)
from IPython.display import Image 
Image(filename='images/task3_6_sketch_resized.png')
